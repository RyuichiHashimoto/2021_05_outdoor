# %%
import numpy as np
import pandas as pd
from lib.io import load_pickle_data

# %%
# !ls /work/data/input/google-smartphone-decimeter-challenge/train/2020-05-14-US-MTV-1/
# Out:
# Pixel4	Pixel4XLModded

# %%
train_data_path =  "/work/data/input/selfmade_dataset/baseline_with_derived_data_v2/train.pkl"
test_data_path =  "/work/data/input/selfmade_dataset/baseline_with_derived_data_v2/test.pkl"

train_df = load_pickle_data(train_data_path)
test_df = load_pickle_data(test_data_path)

# %%
x_columns = [f"svid_ySatPosM_{i}" for i in range(1,38) ]





for key,each_df in train_df.groupby("phone"):

    
    each_df[].plot()
    
    
    
    break;
