# %%
import math
import numpy as np
import pandas as pd
from math import sin, cos, atan2, sqrt
from pyproj import Proj, transform

from cv2 import Rodrigues
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold, TimeSeriesSplit
from sklearn.metrics import accuracy_score
import lightgbm as lgb

from tqdm import tqdm
import pyproj

from lib.noglobal import noglobal




from external_lib.Predict_with_IMU import execute
from external_lib.Predict_with_IMU  import generate_train_data,generate_test_data,training,ECEF_to_WGS84,WGS84_to_ECEF,prepare_imu_data

from lib.io import load_pickle_data
from external_lib.evaluation_function import calc_haversine
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# ## データ取得

# %%
dir_ = "/work/data/input/google-smartphone-decimeter-challenge"
bl_trn_fname = "/work/data/input/google-smartphone-decimeter-challenge/baseline_locations_train.csv"
bl_tst_fname = "/work/data/input/google-smartphone-decimeter-challenge/baseline_locations_test.csv"

sample_fname  = f"{dir_}/sample_submission.csv"

# %%
#train_df = pd.read_csv(bl_trn_fname)
#test_df = pd.read_csv(bl_tst_fname)
bl_trn_df = pd.read_csv(bl_trn_fname)
bl_tst_df = pd.read_csv(bl_tst_fname)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### LightGBM

# %%
from external_lib.Predict_with_IMU import execute
#bl_trn_df = pd.read_csv(bl_trn_fname)
#bl_tst_df = pd.read_csv(bl_tst_fname)

bl_trn_fname = "/work/data/input/selfmade_dataset/baseline_with_derived_data_v5/train.pkl"
bl_tst_fname = "/work/data/input/selfmade_dataset/baseline_with_derived_data_v5/test.pkl"
bl_trn_df = load_pickle_data(bl_trn_fname)
bl_tst_df = load_pickle_data(bl_tst_fname)


tgt_cns = ['2021-04-22-US-SJC-1', '2021-04-28-US-SJC-1', '2021-04-29-US-SJC-2']
tgt_cns = bl_trn_df[bl_trn_df['collectionName'].str.contains("|".join(tgt_cns))]["phone"].unique()
cname_test = '2021-04-29-US-SJC-3'
pname_test = 'SamsungS20Ultra'
test_target_list = [cname_test+"_"+pname_test]


ret_df = execute(bl_trn_df,bl_tst_df,tgt_cns,test_target_list)
# Out:
# 100%|██████████| 6/6 [24:56<00:00, 249.39s/it]
# Final Dataset shape： (14336, 5376)
# [LightGBM] [Warning] bagging_fraction is set=0.7, subsample=0.7 will be ignored. Current value: bagging_fraction=0.7
# [LightGBM] [Warning] early_stopping_round is set=10, early_stopping_rounds=10 will be ignored. Current value: early_stopping_round=10
# [LightGBM] [Warning] feature_fraction is set=0.7, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-4fb8ca192b08> in <module>
#      16
#      17
# ---> 18 ret_df = execute(bl_trn_df,tgt_cns,test_target_list)
#
# /work/src/external_lib/Predict_with_IMU.py in execute(arg_bl_trn_df, train_collection_list, test_collection_list)
#     645
#     646     ## training;
# --> 647     pred_valid_x, pred_test_x = training(df_train, df_test, 'X', params,window_size,folds)
#     648     pred_valid_y, pred_test_y = training(df_train, df_test, 'Y', params,window_size,folds)
#     649     pred_valid_z, pred_test_z = training(df_train, df_test, 'Z', params,window_size,folds)
#
# /work/src/external_lib/Predict_with_IMU.py in training(arg_df_train, arg_df_test, tgt_axis, params, window_size, folds, verbose_flag)
#     597
#     598         pred_valid[val_idx] = lgb_model.predict(X_val, num_iteration =  lgb_model.best_iteration_)
# --> 599         pred_test += lgb_model.predict(df_test[feature_names], num_iteration =  lgb_model.best_iteration_)
#     600
#     601         scores.append(lgb_model.best_score_['valid']['l2'])
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['svid_ySatPosM_18_29', 'svid_xSatPosM_8_28', 'prev_heightAboveWgs84EllipsoidM_13', 'svid_zSatPosM_9_13', 'svid_zSatPosM_11_3', 'svid_ySatPosM_19_28', 'svid_correctedPrM_17_8', 'svid_correctedPrM_6_14', 'svid_correctedPrM_35_11', 'svid_correctedPrM_16_25', 'svid_ySatPosM_3_9', 'svid_correctedPrM_5_29', 'svid_correctedPrM_31_7', 'sv
SatPosM_28_10', 'svid_correctedPrM_36_29', 'svid_ySatPosM_15_9', 'svid_zSatPosM_37_21', 'svid_xSatPosM_24_28', 'svid_ySatPosM_26_25', 'svid_xSatPosM_12_18', 'svid_xSatPosM_13_30', 'svid_xSatPosM_17_25', 'svid_zSatPosM_7_8', 'svid_ySatPosM_34_16', 'svid_xSatPosM_23_20', 'svid_xSatPosM_22_11', 'svid_zSatPosM_20_28', 'svid_correctedPrM_18_18', 'svid_xSatPosM_28_28', 'svid_correctedPrM_9_10', 'svid_xSatPosM_18_25', 'svid_zSatPosM_17_2', 'svid_ySatPosM_26_3', 'svid_zSatPosM_20_3', 'svid_xSatPosM_3_3', 'svid_zSatPosM_14_7', 'svid_zSatPosM_17_11', 'svid_ySatPosM_36_30', 'svid_correctedPrM_28_16', 'svid_xSatPosM_30_9', 'svid_zSatPosM_5_27', 'svid_xSatPosM_11_21', 'svid_xSatPosM_26_27', 'svid_ySatPosM_31_10', 'svid_xSatPosM_23_22', 'svid_correctedPrM_19_25', 'svid_zSatPosM_24_23', 'svid_correctedPrM_17_27', 'svid_xSatPosM_36_12', 'svid_zSatPosM_20_30', 'svid_zSatPosM_21_29', 'svid_ySatPosM_27_19', 'svid_correctedPrM_25_16', 'svid_correctedPrM_21_28', 'svid_zSatPosM_35_4', 'svid_correctedPrM_34_21', 'svid_ySatPosM_6_5', 'svid_zSatPosM_15_25', 'svid_ySatPosM_3_10', 'svid_zSatPosM_9_2', 'svid_ySatPosM_36_15', 'svid_zSatPosM_19_7', 'svid_xSatPosM_2_1', 'svid_co ...

# %%
from external_lib.evaluation_function import evaluate_function,calc_haversine

train_df = ret_df[0]
test_df = ret_df[1]
for key,each_df in train_df[train_df["phone"].str.contains("|".join(tgt_cns))].groupby("phone"):
    a = calc_haversine(each_df["lngDeg_gt"],each_df["latDeg_gt"],each_df["lngDeg_pred"],each_df["latDeg_pred"])
    #print(key,a.iloc[30:].mean())    
    b = calc_haversine(each_df["lngDeg_gt"],each_df["latDeg_gt"],each_df["lngDeg"],each_df["latDeg"])
    
    print("-------------------------------")
    #print(key)
    #display(each_df[["lngDeg","latDeg","latDeg_gt","lngDeg_gt"]].head(40).tail(10))
    print("before",b.iloc[30:].mean())
    print("after",a.iloc[30:].mean())    
    #display(each_df[["latDeg_pred","lngDeg_pred","latDeg_gt","lngDeg_gt"]].head(40).tail(10));
    #display(each_df[["latDeg","lngDeg","latDeg_gt","lngDeg_gt"]].head(40).tail(10));
    break;

# %%
from external_lib.visualize import visualize_trafic
tmpmt = load_pickle_data("/work/data/input/selfmade_dataset/baseline_with_derived_data_v5/train.pkl");

for key,each_df in tmpmt[tmpmt["phone"].str.contains("|".join(tgt_cns))].groupby("phone"):
    a = calc_haversine(each_df["lngDeg_gt"],each_df["latDeg_gt"],each_df["lngDeg"],each_df["latDeg"])
    
    tmp_train_df = train_df[train_df["phone"] == key]
    
    
    print(key,a.iloc[30:].mean())    
    
    
    each_df["label"] = "before"
    tmp_train_df["label"] = "after"
    tmp_train_df[["latDeg","lngDeg"]] = tmp_train_df[["latDeg_pred","lngDeg_pred"]]
    
    display(visualize_trafic(pd.concat([each_df,tmp_train_df]),"label"))
    
    
    break;
    
    #display(each_df[["latDeg","lngDeg","latDeg_gt","lngDeg_gt"]].head(40).tail(10));

# %%
pd.read_csv("/work/data/input/");


#test_df
