# %%
import pandas as pd
from external_lib.visualize import visualize_trafic

from c_library import find_closest_using_multiple_point 

from external_lib.snap_to_grid_to_SJC import generate_grids

from lib.noglobal import noglobal

import geopandas as gpd
from shapely.geometry import Point

import osmnx as ox
import momepy
# Out:
# /opt/conda/lib/python3.7/site-packages/geopandas/_compat.py:110: UserWarning: The Shapely GEOS version (3.8.1-CAPI-1.13.3) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %%
train_df_path = "/work/data/submission_list/baseline_with_snap_to_grid_to_2_or_3_kalman_interplorate_patial_twice/train_result.csv"
train_df = pd.read_csv(train_df_path)

test_df_path = "/work/data/submission_list/baseline_with_snap_to_grid_to_2_or_3_kalman_interplorate_patial_twice/train_result.csv"
test_df = pd.read_csv(test_df_path)

# %%
SJC_list = [i  for i in test_df["phone"].unique().tolist() if "SJC" in i]

print(SJC_list)
# Out:
# ['2021-04-28-US-SJC-1_Pixel4', '2021-04-28-US-SJC-1_SamsungS20Ultra', '2021-04-22-US-SJC-1_Pixel4', '2021-04-22-US-SJC-1_SamsungS20Ultra', '2021-04-29-US-SJC-2_Pixel4', '2021-04-29-US-SJC-2_SamsungS20Ultra']

# %%
import c_library

# %%
each_df = test_df[test_df["phone"] == phone];
tmp_df = each_df.copy()

merged = c_library.merge_points_on_the_road(each_df[["latDeg","lngDeg"]].to_numpy().tolist(),30,1);

tmp_df[["latDeg","lngDeg"]] = merged



each_df["label"] = "dataset"
tmp_df["label"] = "merge_points"

s = pd.concat([each_df,tmp_df]);

# %%
visualize_trafic(s,"label")
#visualize_trafic(tmp_df)
# Out:
# <div>                            <div id="4b235fb6-987e-4283-b34e-a807531fd05c" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b235fb6-987e-4283-b34e-a807531fd05c")) {                    Plotly.newPlot(                        "4b235fb6-987e-4283-b34e-a807531fd05c",                        [{"hovertemplate": "label=dataset<br>latDeg=%{lat}<br>lngDeg=%{lon}<extra></extra>", "lat": [37.334577001394194, 37.334577001394194, 37.334577001394194, 37.334577001394194, 37.334577001394194, 37.334577001394194, 37.334577001394194, 37.334577001394194, 37.334577001394194, 37.334577001394194, 37.334577001394194, 37.334577001394194, 37.334577001394194, 37.334577001394194, 37.334577001394194, 37.334577001394194, 37.334577001394194, 37.334577001394194, 37.33457700139
# ...
